# %%
import geopandas as gpd
import numpy as np
from shapely.geometry import Polygon
import matplotlib.pyplot as plt
import pandas as pd
import rasterio
from shapely.geometry import Point, box
import os

# %%
# data_nyc\zones.geojson

zone = gpd.read_file('../data_nyc/zones.geojson')
zone = zone.reset_index(drop=True)
zone.head()
# Out:
#          ZONEDIST       date  time  \
# 0  ['R3A' 'PARK'] 2024-01-01  0:00
# 1  ['R3A' 'PARK'] 2024-01-01  1:00
# 2  ['R3A' 'PARK'] 2024-01-01  2:00
# 3  ['R3A' 'PARK'] 2024-01-01  3:00
# 4  ['R3A' 'PARK'] 2024-01-01  4:00
#
#                                             geometry
# 0  POLYGON ((913013.301 118296.425, 916294.141 11...
# 1  POLYGON ((913013.301 118296.425, 916294.141 11...
# 2  POLYGON ((913013.301 118296.425, 916294.141 11...
# 3  POLYGON ((913013.301 118296.425, 916294.141 11...
# 4  POLYGON ((913013.301 118296.425, 916294.141 11...

# %%
minx, miny, maxx, maxy = zone.total_bounds
bbox = box(minx, miny, maxx, maxy)

# %%
temp = zone.copy()
temp.head()

# save temp
# temp.to_file('../data_nyc/temp.geojson', driver='GeoJSON')
# Out:
#          ZONEDIST       date  time  \
# 0  ['R3A' 'PARK'] 2024-01-01  0:00
# 1  ['R3A' 'PARK'] 2024-01-01  1:00
# 2  ['R3A' 'PARK'] 2024-01-01  2:00
# 3  ['R3A' 'PARK'] 2024-01-01  3:00
# 4  ['R3A' 'PARK'] 2024-01-01  4:00
#
#                                             geometry
# 0  POLYGON ((913013.301 118296.425, 916294.141 11...
# 1  POLYGON ((913013.301 118296.425, 916294.141 11...
# 2  POLYGON ((913013.301 118296.425, 916294.141 11...
# 3  POLYGON ((913013.301 118296.425, 916294.141 11...
# 4  POLYGON ((913013.301 118296.425, 916294.141 11...

# %%
temp.crs
# Out:
# <Projected CRS: EPSG:2263>
# Name: NAD83 / New York Long Island (ftUS)
# Axis Info [cartesian]:
# - X[east]: Easting (US survey foot)
# - Y[north]: Northing (US survey foot)
# Area of Use:
# - name: United States (USA) - New York - counties of Bronx; Kings; Nassau; New York; Queens; Richmond; Suffolk.
# - bounds: (-74.26, 40.47, -71.8, 41.3)
# Coordinate Operation:
# - name: SPCS83 New York Long Island zone (US survey foot)
# - method: Lambert Conic Conformal (2SP)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
# ozone
# data\ozone_2024.csv

ozone = pd.read_csv('../data/ozone_2024.csv', low_memory=False)

# %%
ozone.columns
# Out:
# Index(['State Code', 'County Code', 'Site Num', 'Parameter Code', 'POC',
#        'Latitude', 'Longitude', 'Datum', 'Parameter Name', 'Date Local',
#        'Time Local', 'Date GMT', 'Time GMT', 'Sample Measurement',
#        'Units of Measure', 'MDL', 'Uncertainty', 'Qualifier', 'Method Type',
#        'Method Code', 'Method Name', 'State Name', 'County Name',
#        'Date of Last Change'],
#       dtype='object')

# %%
# 'State Code', 'County Code', 'Site Num', 'Parameter Code', 'Latitude', 'Longitude', 'Datum', 'Date Local',
# 'Time Local', 'Sample Measurement', 'Units of Measure', 'Uncertainty', 'State Name', 'County Name'

params = ['State Code', 'County Code', 'Site Num', 'Parameter Code', 'Latitude', 'Longitude', 'Datum', 'Date Local','Time Local', 'Sample Measurement', 'Units of Measure', 'Uncertainty', 'State Name', 'County Name']
ozone = ozone[params]

# %%
ozone_gdf = gpd.GeoDataFrame(
    ozone,
    geometry=[Point(xy) for xy in zip(ozone['Longitude'], ozone['Latitude'])],
    crs='EPSG:4326'
)
ozone_gdf = ozone_gdf.to_crs('EPSG:2263')
ozone_gdf = ozone_gdf[ozone_gdf.geometry.within(bbox)]

# %%
ozone_gdf.rename(columns={'Date Local': 'date', 'Time Local': 'time', 'Sample Measurement': 'ozone measurement', 'Units of Measure': 'ozone unit'}, inplace=True)
ozone_temp = ozone_gdf.copy()
ozone_temp = ozone_temp[['date', 'time', 'ozone measurement', 'ozone unit', 'geometry']]
ozone_temp.head()
# Out:
#                date   time  ozone measurement         ozone unit  \
# 3327580  2024-02-16  10:00              0.032  Parts per million
# 3327581  2024-02-16  11:00              0.032  Parts per million
# 3327582  2024-02-16  12:00              0.032  Parts per million
# 3327583  2024-02-16  13:00              0.033  Parts per million
# 3327584  2024-02-16  14:00              0.033  Parts per million
#
#                               geometry
# 3327580  POINT (986464.161 256401.225)
# 3327581  POINT (986464.161 256401.225)
# 3327582  POINT (986464.161 256401.225)
# 3327583  POINT (986464.161 256401.225)
# 3327584  POINT (986464.161 256401.225)

# %%
temp['date'] = pd.to_datetime(temp['date']).dt.date
ozone_temp['date'] = pd.to_datetime(ozone_temp['date']).dt.date

temp   ['time'] = pd.to_datetime(temp['time'], format='%H:%M').dt.strftime('%H:%M')
ozone_temp['time'] = pd.to_datetime(ozone_temp['time'], format='%H:%M').dt.strftime('%H:%M')


all_results = []

# loop over dates, '2024-01-01', ..., '2024-06-30'
for current_date in pd.date_range('2024-01-01','2024-06-30',freq='D'):
    d = current_date.date()             
    temp_d = temp[temp['date']==d]
    if temp_d.empty: 
        continue
    
    # loop over hours, '00', '01', ..., '23'
    for hour in range(24):
        time_label = f"{hour:02d}:00" 
        temp_h = temp_d[temp_d['time']==time_label]
        ozone_h   = ozone_temp[
            (ozone_temp['date']==d) & 
            (ozone_temp['time']==time_label)
        ]
        if temp_h.empty or ozone_h.empty:
            continue

        joined = gpd.sjoin(
            temp_h,
            ozone_h[['geometry','ozone measurement']],
            how='left',
            predicate='contains'
        ).drop(columns=['index_right'])

        agg = (
            joined
            .groupby(['date','time','geometry'])['ozone measurement']
            .mean()
            .reset_index()
            
        )
        agg = gpd.GeoDataFrame(agg, geometry='geometry', crs=temp_h.crs)

        res_h = temp_h.merge(
            agg[['date','time','geometry','ozone measurement']],
            on=['date','time','geometry'],
            how='left'
        )
        all_results.append(res_h)

# %%
result = gpd.GeoDataFrame(
    pd.concat(all_results, ignore_index=True),
    geometry='geometry',
    crs=temp.crs
)
result
# Out:
#                                    ZONEDIST        date   time  \
# 0                            ['R3A' 'PARK']  2024-01-01  00:00
# 1        ['R3A' 'R3-2' 'R3X' 'R1-2' 'PARK']  2024-01-01  00:00
# 2                     ['R1-2' 'R3X' 'R1-1']  2024-01-01  00:00
# 3                                   [ NaN ]  2024-01-01  00:00
# 4                                   [ NaN ]  2024-01-01  00:00
# ...                                     ...         ...    ...
# 9648907                             [ NaN ]  2024-06-30  23:00
# 9648908                             [ NaN ]  2024-06-30  23:00
# 9648909                             [ NaN ]  2024-06-30  23:00
# 9648910                             [ NaN ]  2024-06-30  23:00
# 9648911                             [ NaN ]  2024-06-30  23:00
#
#                                                   geometry  ozone measurement
# 0        POLYGON ((913013.301 118296.425, 916294.141 11...                NaN
# 1        POLYGON ((916294.141 118296.425, 919574.981 11...                NaN
# 2        POLYGON ((919574.981 118296.425, 922855.821 11...                NaN
# 3        POLYGON ((922855.821 118296.425, 926136.661 11...                NaN
# 4        POLYGON ((926136.661 118296.425, 929417.501 11...                NaN
# ...                                                    ...                ...
# 9648907  POLYGON ((1050808.581 269215.065, 1054089.421 ...                NaN
# 9648908  POLYGON ((1054089.421 269215.065, 1057370.261 ...                NaN
# 9648909  POLYGON ((1057370.261 269215.065, 1060651.101 ...                NaN
# 9648910  POLYGON ((1060651.101 269215.065, 1063931.941 ...                NaN
# 9648911  POLYGON ((1063931.941 269215.065, 1067212.781 ...                NaN
#
# [9648912 rows x 5 columns]

# %%
print(result.columns.tolist())
# Out:
# ['ZONEDIST', 'date', 'time', 'geometry', 'ozone measurement']

# %%
mask = (
    (result['date'] == pd.to_datetime('2024-01-01').date()) &
    (result['time'] == '00:00')
)
slice_0000 = result[mask]

fig, ax = plt.subplots(figsize=(10, 10))
slice_0000.plot(
    column='ozone measurement',
    legend=True,
    edgecolor='black',
    missing_kwds={'color': 'white'},
    ax=ax
)
ax.set_title('ozone Measurement at 2024-01-01 00:00')
ax.set_axis_off()
plt.tight_layout()
plt.show()

# %%
# save result
result['time'] = result['time'].apply(lambda x: x.strftime('%H:%M') if not isinstance(x, str) else x)
result.to_file('../data_nyc/ozone.geojson', driver='GeoJSON')

# %%
result.to_csv('../data_nyc/ozone.csv', index=False)

# %%
result
# Out:
#                                    ZONEDIST        date   time  \
# 0                            ['R3A' 'PARK']  2024-01-01  00:00
# 1        ['R3A' 'R3-2' 'R3X' 'R1-2' 'PARK']  2024-01-01  00:00
# 2                     ['R1-2' 'R3X' 'R1-1']  2024-01-01  00:00
# 3                                   [ NaN ]  2024-01-01  00:00
# 4                                   [ NaN ]  2024-01-01  00:00
# ...                                     ...         ...    ...
# 9648907                             [ NaN ]  2024-06-30  23:00
# 9648908                             [ NaN ]  2024-06-30  23:00
# 9648909                             [ NaN ]  2024-06-30  23:00
# 9648910                             [ NaN ]  2024-06-30  23:00
# 9648911                             [ NaN ]  2024-06-30  23:00
#
#                                                   geometry  ozone measurement
# 0        POLYGON ((913013.301 118296.425, 916294.141 11...                NaN
# 1        POLYGON ((916294.141 118296.425, 919574.981 11...                NaN
# 2        POLYGON ((919574.981 118296.425, 922855.821 11...                NaN
# 3        POLYGON ((922855.821 118296.425, 926136.661 11...                NaN
# 4        POLYGON ((926136.661 118296.425, 929417.501 11...                NaN
# ...                                                    ...                ...
# 9648907  POLYGON ((1050808.581 269215.065, 1054089.421 ...                NaN
# 9648908  POLYGON ((1054089.421 269215.065, 1057370.261 ...                NaN
# 9648909  POLYGON ((1057370.261 269215.065, 1060651.101 ...                NaN
# 9648910  POLYGON ((1060651.101 269215.065, 1063931.941 ...                NaN
# 9648911  POLYGON ((1063931.941 269215.065, 1067212.781 ...                NaN
#
# [9648912 rows x 5 columns]
